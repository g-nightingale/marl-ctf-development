# %% [markdown]
# # Analysis

# %%
from gridworld_ctf import GridworldCtf
import numpy as np
from scenarios import CtfScenarios as scn
from utils import get_agents, create_gif, create_plots, plot_heatmaps, \
                  duel, TrainingConfig

# %% [markdown]
# ### Experiment 1: Arrow

# %%
# Create training plots
create_plots('runs/0_arrow/',
            ['time_capsule_0_50.bin',
             'time_capsule_1_50.bin',
             'time_capsule_2_50.bin'
             ])
# Out:
# runs/0_arrow/time_capsule_0_50.bin
# runs/0_arrow/time_capsule_1_50.bin
# runs/0_arrow/time_capsule_2_50.bin

# %%
# Retrieve agents from time capsule
env_config, agent1, agent2 = get_agents('runs/0_arrow/',
                                        'time_capsule_0_50.bin',
                                        0,
                                        0,
                                        1,
                                        0)

# Create environment with loaded config                         
env = GridworldCtf(**env_config)

# Render a duel
_, _, _ = duel(env, 
                agent1, 
                agent2, 
                (0, 1), 
                max_steps=500, 
                render=True,
                sleep_time=0.05)
# Out:
# 500 1 4

# %%
# Plot heatmaps from the latest run
plot_heatmaps(env)

# %%
# Generate an animated gif
create_gif(env, 
            agent1, 
            agent2, 
            max_frames=250,
            gif_folder='/gifs/0_arrow/',
            gif_name='arrow.gif',
            delete_temp_files=False,
            duration=200)

# %% [markdown]
# ### Experiment 2: The Fence

# %%
# Create training plots
create_plots('runs/1_the_fence/',
            ['time_capsule_0_50.bin',
             'time_capsule_1_50.bin',
             'time_capsule_2_50.bin'])
# Out:
# runs/1_the_fence/time_capsule_0_50.bin
# runs/1_the_fence/time_capsule_1_50.bin
# runs/1_the_fence/time_capsule_2_50.bin

# %%
# Retrieve agents from time capsule
env_config, agent1, agent2 = get_agents('runs/1_the_fence/',
                                        'time_capsule_0_50.bin',
                                        0,
                                        0,
                                        1,
                                        0)

# Create environment with loaded config                         
env = GridworldCtf(**env_config)

# Render a duel
_, _, _ = duel(env, 
                agent1, 
                agent2, 
                (0, 1), 
                max_steps=500, 
                render=True,
                sleep_time=0.05)
# Out:
# 500 17 23

# %%
# Plot heatmaps from the latest run
plot_heatmaps(env)

# %%
# Generate an animated gif
create_gif(env, 
            agent1, 
            agent2, 
            max_frames=250,
            gif_folder='/gifs/0_the_fence/',
            gif_name='arrow.gif',
            delete_temp_files=False,
            duration=200)

# %% [markdown]
# ### Experiment 3: Jailbreak

# %%
# Create training plots
create_plots('runs/2_jailbreak/',
            ['time_capsule_0_50.bin'])
# Out:
# runs/2_jailbreak/time_capsule_0_50.bin
