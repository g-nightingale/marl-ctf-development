# %% [markdown]
# # Analysis

# %%
from gridworld_ctf import GridworldCtf
import numpy as np
from scenarios import CtfScenarios as scn
from utils import get_agents, create_gif, create_plots, plot_heatmaps, \
                  duel, TrainingConfig

# %% [markdown]
# ### Experiment 1: Arrow

# %%
# Create training plots
create_plots('runs/0_arrow/',
            ['time_capsule_0_50.bin',
             'time_capsule_1_50.bin',
             'time_capsule_2_50.bin',
             'time_capsule_3_50.bin',
             'time_capsule_4_50.bin'])
            #  'time_capsule_5_50.bin',
            #  'time_capsule_6_50.bin',
            #  'time_capsule_7_50.bin',
            #  'time_capsule_8_50.bin',
            #  'time_capsule_9_50.bin'])
# Out:
# runs/0_arrow/time_capsule_0_50.bin
# runs/0_arrow/time_capsule_1_50.bin
# runs/0_arrow/time_capsule_2_50.bin
# runs/0_arrow/time_capsule_3_50.bin
# runs/0_arrow/time_capsule_4_50.bin

# %%
# Retrieve agents from time capsule
env_config, agent1, agent2 = get_agents('runs/0_arrow/',
                                        'time_capsule_0_50.bin',
                                        0,
                                        0,
                                        1,
                                        0)

# Create environment with loaded config                         
env = GridworldCtf(**env_config)

# Render a duel
_, _, _ = duel(env, 
                agent1, 
                agent2, 
                (0, 1), 
                max_steps=500, 
                render=True,
                sleep_time=0.05)
# Out:
# 500 3 5

# %%
# Plot heatmaps from the latest run
plot_heatmaps(env)

# %%
# Generate an animated gif
create_gif(env, 
            agent1, 
            agent2, 
            max_frames=250,
            gif_folder='/gifs/0_arrow/',
            gif_name='arrow.gif',
            delete_temp_files=False,
            duration=200)

# %% [markdown]
# ### Experiment 2: The Fence

# %%
# Create training plots
create_plots('runs/1_fence/',
            ['time_capsule_0_50.bin',
             'time_capsule_1_50.bin',
             'time_capsule_2_50.bin',
             'time_capsule_3_50.bin',
             'time_capsule_4_50.bin',
             'time_capsule_5_50.bin',
             'time_capsule_6_50.bin',
             'time_capsule_7_50.bin',
             'time_capsule_8_50.bin',
             'time_capsule_9_50.bin'])
# Out:
# runs/1_fence/time_capsule_0_50.bin
# runs/1_fence/time_capsule_1_50.bin
# runs/1_fence/time_capsule_2_50.bin
# runs/1_fence/time_capsule_3_50.bin
# runs/1_fence/time_capsule_4_50.bin
# runs/1_fence/time_capsule_5_50.bin
# runs/1_fence/time_capsule_6_50.bin
# runs/1_fence/time_capsule_7_50.bin
# runs/1_fence/time_capsule_8_50.bin
# runs/1_fence/time_capsule_9_50.bin

# %%
# Retrieve agents from time capsule
env_config, agent1, agent2 = get_agents('runs/1_fence/',
                                        'time_capsule_0_50.bin',
                                        0,
                                        0,
                                        1,
                                        0)

# Create environment with loaded config                         
env = GridworldCtf(**env_config)

# Render a duel
_, _, _ = duel(env, 
                agent1, 
                agent2, 
                (0, 1), 
                max_steps=500, 
                render=True,
                sleep_time=0.05)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/geoffrey.nightingale@contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb Cell 10 in 1
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X12sZmlsZQ%3D%3D?line=9'>10</a> env = GridworldCtf(**env_config)
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X12sZmlsZQ%3D%3D?line=11'>12</a> # Render a duel
# ---> <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X12sZmlsZQ%3D%3D?line=12'>13</a> _, _, _ = duel(env,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X12sZmlsZQ%3D%3D?line=13'>14</a>                 agent1,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X12sZmlsZQ%3D%3D?line=14'>15</a>                 agent2,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X12sZmlsZQ%3D%3D?line=15'>16</a>                 (0, 1),
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X12sZmlsZQ%3D%3D?line=16'>17</a>                 max_steps=500,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X12sZmlsZQ%3D%3D?line=17'>18</a>                 render=True,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X12sZmlsZQ%3D%3D?line=18'>19</a>                 sleep_time=0.05)
#
# File ~/Documents/code/marl-ctf-development/mvp_environment/utils.py:410, in duel(env, agent, opponent, idxs, return_result, device, max_steps, render, sleep_time)
#     407 _, _, done = env.step(actions)
#     409 if render:
# --> 410     env.render(sleep_time=sleep_time)
#     411     print(step_count, env.metrics['team_flag_captures'][0], env.metrics['team_flag_captures'][1])
#     413 if step_count > max_steps:
#
# File ~/Documents/code/marl-ctf-development/mvp_environment/gridworld_ctf.py:1097, in GridworldCtf.render(self, sleep_time, ego_state_agent)
#    1095 ax.set_xticks(np.arange(-0.5, env_plot.shape[1] , 1))
#    1096 ax.set_xticklabels([])
# -> 1097 ax.set_yticks(np.arange(-0.5, env_plot.shape[0], 1))
#    1098 ax.set_yticklabels([])
#    1100 plt.show()
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/matplotlib/axes/_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/matplotlib/axis.py:2030, in Axis.set_ticks(self, ticks, labels, minor, **kwargs)
#    1996 def set_ticks(self, ticks, labels=None, *, minor=False, **kwargs):
#    1997     """
#    1998     Set this Axis' tick locations and optionally labels.
#    1999
#    (...)
#    2028     ticks.
#    2029     """
# -> 2030     result = self._set_tick_locations(ticks, minor=minor)
#    2031     if labels is not None:
#    2032         self.set_ticklabels(labels, minor=minor, **kwargs)
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/matplotlib/axis.py:1994, in Axis._set_tick_locations(self, ticks, minor)
#    1992 else:
#    1993     self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1994     return self.get_major_ticks(len(ticks))
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/matplotlib/axis.py:1534, in Axis.get_major_ticks(self, numticks)
#    1530     numticks = len(self.get_majorticklocs())
#    1532 while len(self.majorTicks) < numticks:
#    1533     # Update the new tick label properties from the old.
# -> 1534     tick = self._get_tick(major=True)
#    1535     self.majorTicks.append(tick)
#    1536     self._copy_tick_props(self.majorTicks[0], tick)
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/matplotlib/axis.py:1483, in Axis._get_tick(self, major)
#    1479     raise NotImplementedError(
#    1480         f"The Axis subclass {self.__class__.__name__} must define "
#    1481         "_tick_class or reimplement _get_tick()")
#    1482 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1483 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/matplotlib/axis.py:493, in YTick.__init__(self, *args, **kwargs)
#     490 self.gridline.set(
#     491     data=([0, 1], [0, 0]), transform=ax.get_yaxis_transform("grid"))
#     492 # the y loc is 3 points below the min of y axis
# --> 493 trans, va, ha = self._get_text1_transform()
#     494 self.label1.set(
#     495     x=0, y=0,
#     496     verticalalignment=va, horizontalalignment=ha, transform=trans,
#     497 )
#     498 trans, va, ha = self._get_text2_transform()
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/matplotlib/axis.py:505, in YTick._get_text1_transform(self)
#     504 def _get_text1_transform(self):
# --> 505     return self.axes.get_yaxis_text1_transform(self._pad)
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/matplotlib/axes/_base.py:997, in _AxesBase.get_yaxis_text1_transform(self, pad_points)
#     976 """
#     977 Returns
#     978 -------
#    (...)
#     993 may need to place axis elements in different locations.
#     994 """
#     995 labels_align = mpl.rcParams["ytick.alignment"]
#     996 return (self.get_yaxis_transform(which='tick1') +
# --> 997         mtransforms.ScaledTranslation(-1 * pad_points / 72, 0,
#     998                                       self.figure.dpi_scale_trans),
#     999         labels_align, "right")
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/matplotlib/transforms.py:2679, in ScaledTranslation.__init__(self, xt, yt, scale_trans, **kwargs)
#    2678 def __init__(self, xt, yt, scale_trans, **kwargs):
# -> 2679     super().__init__(**kwargs)
#    2680     self._t = (xt, yt)
#    2681     self._scale_trans = scale_trans
#
# KeyboardInterrupt:

# %%
# Plot heatmaps from the latest run
plot_heatmaps(env)

# %%
# Generate an animated gif
create_gif(env, 
            agent1, 
            agent2, 
            max_frames=100,
            gif_folder='/gifs/1_fence/',
            gif_name='fence.gif',
            delete_temp_files=False,
            duration=200)

# %% [markdown]
# ### Experiment 3: Jailbreak

# %%
# Create training plots
create_plots('runs/2_jailbreak/',
            ['time_capsule_0_20.bin',
            'time_capsule_1_20.bin',
            'time_capsule_2_20.bin'])
# Out:
# runs/2_jailbreak/time_capsule_0_20.bin
# runs/2_jailbreak/time_capsule_1_20.bin
# runs/2_jailbreak/time_capsule_2_20.bin

# %%
# Retrieve agents from time capsule
env_config, agent1, agent2 = get_agents('runs/2_jailbreak/',
                                        'time_capsule_0_20.bin',
                                        0,
                                        0,
                                        1,
                                        0)

# Create environment with loaded config                         
env = GridworldCtf(**env_config)

# Render a duel
_, _, _ = duel(env, 
                agent1, 
                agent2, 
                (0, 1), 
                max_steps=500, 
                render=True,
                sleep_time=0.05)
# Out:
# runs/2_jailbreak/time_capsule_0_20.bin
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/geoffrey.nightingale@contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb Cell 15 in 1
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X20sZmlsZQ%3D%3D?line=9'>10</a> env = GridworldCtf(**env_config)
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> # Render a duel
# ---> <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X20sZmlsZQ%3D%3D?line=12'>13</a> _, _, _ = duel(env,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X20sZmlsZQ%3D%3D?line=13'>14</a>                 agent1,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X20sZmlsZQ%3D%3D?line=14'>15</a>                 agent2,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X20sZmlsZQ%3D%3D?line=15'>16</a>                 (0, 1),
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X20sZmlsZQ%3D%3D?line=16'>17</a>                 max_steps=500,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X20sZmlsZQ%3D%3D?line=17'>18</a>                 render=True,
#      <a href='vscode-notebook-cell:/Users/geoffrey.nightingale%40contino.io/Documents/code/marl-ctf-development/mvp_environment/analysis.ipynb#X20sZmlsZQ%3D%3D?line=18'>19</a>                 sleep_time=0.05)
#
# File ~/Documents/code/marl-ctf-development/mvp_environment/utils.py:400, in duel(env, agent, opponent, idxs, return_result, device, max_steps, render, sleep_time)
#     393 metadata_state[agent_idx] = torch.tensor(
#     394     env.get_env_metadata(agent_idx),
#     395     dtype=torch.float32,
#     396     device=device,
#     397 )
#     399 if env.AGENT_TEAMS[agent_idx] == 0:
# --> 400     action = agent.get_action(grid_state[agent_idx], metadata_state[agent_idx], use_action_mask[agent_idx])
#     401 else:
#     402     action = opponent.get_action(grid_state[agent_idx], metadata_state[agent_idx], use_action_mask[agent_idx])
#
# File ~/Documents/code/marl-ctf-development/mvp_environment/agent_network.py:43, in Agent.get_action(self, x, x2, masking_decision_tensor)
#      42 def get_action(self, x, x2, masking_decision_tensor):
# ---> 43     _, logits = self(x, x2)
#      45     mask_5 = self.mask_5
#      46     if len(logits.shape) == 2:
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1480, in Module._call_impl(self, *args, **kwargs)
#    1475 # If we don't have any hooks, we want to skip the rest of the logic in
#    1476 # this function, and just call forward.
#    1477 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1478         or _global_backward_pre_hooks or _global_backward_hooks
#    1479         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1480     return forward_call(*args, **kwargs)
#    1481 # Do not call functions when jit is used
#    1482 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/Documents/code/marl-ctf-development/mvp_environment/agent_network.py:31, in Agent.forward(self, x, x2)
#      30 def forward(self, x, x2):
# ---> 31     x = torch.tanh(self.conv1(x))
#      32     x = torch.tanh(self.conv2(x))
#      33     x = x.view(-1, self.unrolled_conv_size)
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/torch/nn/modules/module.py:1480, in Module._call_impl(self, *args, **kwargs)
#    1475 # If we don't have any hooks, we want to skip the rest of the logic in
#    1476 # this function, and just call forward.
#    1477 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1478         or _global_backward_pre_hooks or _global_backward_hooks
#    1479         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1480     return forward_call(*args, **kwargs)
#    1481 # Do not call functions when jit is used
#    1482 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/torch/nn/modules/conv.py:463, in Conv2d.forward(self, input)
#     462 def forward(self, input: Tensor) -> Tensor:
# --> 463     return self._conv_forward(input, self.weight, self.bias)
#
# File ~/opt/anaconda3/envs/torch-env/lib/python3.9/site-packages/torch/nn/modules/conv.py:459, in Conv2d._conv_forward(self, input, weight, bias)
#     455 if self.padding_mode != 'zeros':
#     456     return F.conv2d(F.pad(input, self._reversed_padding_repeated_twice, mode=self.padding_mode),
#     457                     weight, bias, self.stride,
#     458                     _pair(0), self.dilation, self.groups)
# --> 459 return F.conv2d(input, weight, bias, self.stride,
#     460                 self.padding, self.dilation, self.groups)
#
# RuntimeError: Given groups=1, weight of size [16, 11, 3, 3], expected input[1, 10, 11, 11] to have 11 channels, but got 10 channels instead

# %% [markdown]
# ### Experiment 4. One way out

# %%
# Create training plots
create_plots('runs/3_one_way_out/',
            ['time_capsule_0_50.bin',
             'time_capsule_1_50.bin',
            #  'time_capsule_2_50.bin',
             'time_capsule_3_50.bin',
             'time_capsule_4_50.bin'])
# Out:
# runs/3_one_way_out/time_capsule_0_50.bin
# runs/3_one_way_out/time_capsule_1_50.bin
# runs/3_one_way_out/time_capsule_3_50.bin
# runs/3_one_way_out/time_capsule_4_50.bin

# %%
# Retrieve agents from time capsule
env_config, agent1, agent2 = get_agents('runs/3_one_way_out/',
                                        'time_capsule_4_50.bin',
                                        0,
                                        0,
                                        1,
                                        0)

# Create environment with loaded config                         
env = GridworldCtf(**env_config)

# Render a duel
_, _, _ = duel(env, 
                agent1, 
                agent2, 
                (0, 1), 
                max_steps=500, 
                render=True,
                sleep_time=0.05)
# Out:
# 500 60 2

# %%
# Plot heatmaps from the latest run
plot_heatmaps(env)

# %%
# Generate an animated gif
create_gif(env, 
            agent1, 
            agent2, 
            max_frames=250,
            gif_folder='/gifs/3_one_way_out/',
            gif_name='one_way_out_2.gif',
            delete_temp_files=True,
            duration=200)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

CWD = os.getcwd()

# Paths to your images
image_paths = ['/img/scout_blue.png', '/img/guardian_blue.png', '/img/vaulter_blue.png', '/img/miner_blue.png']

# Titles for your images
image_titles = ['Scout', 'Guardian', 'Vaulter', 'Miner']

# Create a new figure
plt.figure(figsize=(10, 2))  # figure size in inches, you can adjust as per your needs

# Display each image
for i in range(4):
    plt.subplot(1, 4, i+1)  # arguments are nrows, ncols, index

    # Open the image file
    img = Image.open(CWD + image_paths[i])

    # Display the image
    plt.imshow(img)

    # Set the title
    plt.title(image_titles[i])

    # Optional: remove axis
    plt.axis('off')

plt.show()

# %%
# Paths to your images
image_paths = ['/img/tile0.png', 
               '/img/tile1.png', 
               '/img/tile2.png', 
               '/img/tile3.png', 
               '/img/flag_blue.png',
               '/img/flag_red.png']

# Titles for your images
image_titles = ['Free tile', 
                'Block tile', 
                'Destr. tile 1', 
                'Destr. tile 2',
                'Blue flag',
                'Red flag'
                ]

# Create a new figure
plt.figure(figsize=(10, 2))  # figure size in inches, you can adjust as per your needs

# Display each image
for i in range(6):
    plt.subplot(1, 6, i+1)  # arguments are nrows, ncols, index

    # Open the image file
    img = Image.open(CWD + image_paths[i])

    # Display the image
    plt.imshow(img)

    # Set the title
    plt.title(image_titles[i])

    # Optional: remove axis
    plt.axis('off')

plt.show()
